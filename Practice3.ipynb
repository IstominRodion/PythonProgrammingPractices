# %%
class MotoBase:
    def __init__(self, brand : str, raceType : str):
        ''' Инициализурет объект мото '''
        self.brand = brand
        self.raceType = raceType # Тип гонок, для которых предназначен мотоцикл

# %%
class CrossMoto(MotoBase):
    def __init__(self, brand: str, engineVolume : int):
        ''' Инициализирует класс кроссового мотоцикла'''
        super().__init__(brand, 'cross')
        self.engineVolume = engineVolume
    
    def __call__(self):
        return 'brap brap'
    
    def __repr__(self) -> str:
        return f'CrossMoto(brand = {self.brand}, engineVolume = {self.engineVolume})'

# %%
class MotoBase:
    def __init__(self, brand : str, raceType : str):
        ''' Инициализурет объект мото '''
        self.brand = brand
        self.raceType = raceType # Тип гонок, для которых предназначен мотоцикл
    
    def __str__(self):
        return 'moto does' + self.__call__

# %%
class MotoBase:
    def __init__(self, brand : str, raceType : str):
        ''' Инициализурет объект мото '''
        self.brand = brand
        self.raceType = raceType # Тип гонок, для которых предназначен мотоцикл
    
    def __str__(self):
        return 'moto does' + self.__call__
    
    def __call__(self):
        return 'wroom wroom'

# %%
class RoadMoto(MotoBase):
    def __init__(self, brand: str):
        super().__init__(brand, 'road')

# %%
roadMoto = RoadMoto('nonda')

# %%
crossMoto = CrossMoto('honda', 250)

# %%
roadMoto

# %%
roadMoto()
# Out:
# 'wroom wroom'

# %%
print(roadMoto)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 print(roadMoto)
#
# Cell In [4], line 8, in MotoBase.__str__(self)
#       7 def __str__(self):
# ----> 8     return 'moto does' + self.__call__
#
# TypeError: can only concatenate str (not "method") to str

# %%
class MotoBase:
    def __init__(self, brand : str, raceType : str):
        ''' Инициализурет объект мото '''
        self.brand = brand
        self.raceType = raceType # Тип гонок, для которых предназначен мотоцикл
    
    def __str__(self):
        return 'moto does' + self.__call__()
    
    def __call__(self):
        return 'wroom wroom'

# %%
class MotoBase:
    def __init__(self, brand : str, raceType : str):
        ''' Инициализурет объект мото '''
        self.brand = brand
        self.raceType = raceType # Тип гонок, для которых предназначен мотоцикл
    
    def __str__(self):
        return 'moto does' + self()
    
    def __call__(self):
        return 'wroom wroom'

# %%
print(roadMoto)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 print(roadMoto)
#
# Cell In [4], line 8, in MotoBase.__str__(self)
#       7 def __str__(self):
# ----> 8     return 'moto does' + self.__call__
#
# TypeError: can only concatenate str (not "method") to str

# %%
roadMoto = RoadMoto()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 roadMoto = RoadMoto()
#
# TypeError: RoadMoto.__init__() missing 1 required positional argument: 'brand'

# %%
roadMoto = RoadMoto('honda')

# %%
print(roadMoto)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 print(roadMoto)
#
# Cell In [4], line 8, in MotoBase.__str__(self)
#       7 def __str__(self):
# ----> 8     return 'moto does' + self.__call__
#
# TypeError: can only concatenate str (not "method") to str

# %%
class RoadMoto(MotoBase):
    def __init__(self, brand: str):
        super().__init__(brand, 'road')

# %%
roadMoto = RoadMoto('honda')

# %%
print(roadMoto)
# Out:
# moto doeswroom wroom

# %%
crossMoto()
# Out:
# 'brap brap'

# %%
str(crossMoto)
# Out:
# 'CrossMoto(brand = honda, engineVolume = 250)'

# %%
print(crossMoto)
# Out:
# CrossMoto(brand = honda, engineVolume = 250)

# %%
crossMoto.__str__()
# Out:
# 'CrossMoto(brand = honda, engineVolume = 250)'

# %%
class CrossMoto(MotoBase):
    def __init__(self, brand: str, engineVolume : int):
        ''' Инициализирует класс кроссового мотоцикла'''
        super().__init__(brand, 'cross')
        self.engineVolume = engineVolume
    
    def __call__(self):
        return 'brap brap'
    
    def __repr__(self) -> str:
        return f'CrossMoto(brand = {self.brand}, engineVolume = {self.engineVolume})'

# %%
crossMoto = CrossMoto('yamaha', 250)

# %%
print(crossMoto)
# Out:
# moto doesbrap brap

# %%
crossMoto.__repr__()
# Out:
# 'CrossMoto(brand = yamaha, engineVolume = 250)'

# %%
newCrossMoto = CrossMoto(brand = yamaha, engineVolume = 250)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [28], line 1
# ----> 1 newCrossMoto = CrossMoto(brand = yamaha, engineVolume = 250)
#
# NameError: name 'yamaha' is not defined

# %%
class CrossMoto(MotoBase):
    def __init__(self, brand: str, engineVolume : int):
        ''' Инициализирует класс кроссового мотоцикла'''
        super().__init__(brand, 'cross')
        self.engineVolume = engineVolume
    
    def __call__(self):
        return 'brap brap'
    
    def __repr__(self) -> str:
        return f'CrossMoto(brand = "{self.brand}", engineVolume = {self.engineVolume})'

# %%
newCrossMoto = CrossMoto(brand = "yamaha", engineVolume = 250)

# %%
newCrossMoto
# Out:
# CrossMoto(brand = "yamaha", engineVolume = 250)

# %%
print(newCrossMoto)
# Out:
# moto doesbrap brap
