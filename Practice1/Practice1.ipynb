# %%
'''Практика 1
на примере предметной области мотоциклов'''
# Out:
# 'Практика 1\nна примере предметной области мотоциклов'

# %%
brand = 'honda'

# %%
engineVolume = '1000'

# %%
engineVolume = 1000

# %%
engineVolume = engineVolume + 1

# %%
engineVolume
# Out:
# 1001

# %%
engineVolume = engineVolume - 1 + '1'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 engineVolume = engineVolume - 1 + '1'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
engineVolume = str(engineVolume - 1) + '1'

# %%
engineVolume
# Out:
# '10001'

# %%
class Moto:
    def __init__(self, brand, volume):
        self.Brand = brand
        self.EngineVolume = volume

    def Print(self):
        print('Brand: {brand}} EngineVolume = {EngineVolume}}'.format(brand = self.Brand, EngineVolume = self.EngineVolume))

# %%
moto = Moto()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 moto = Moto()
#
# TypeError: Moto.__init__() missing 2 required positional arguments: 'brand' and 'volume'

# %%
moto = Moto('Yamaha', 250)

# %%
moto.Print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 moto.Print()
#
# Cell In [10], line 7, in Moto.Print(self)
#       6 def Print(self):
# ----> 7     print('Brand: {brand}} EngineVolume = {EngineVolume}}'.format(brand = self.Brand, EngineVolume = self.EngineVolume))
#
# ValueError: Single '}' encountered in format string

# %%
# oops

# %%
class NewMoto:
    def __init__(self, brand, volume):
        self.Brand = brand
        self.EngineVolume = volume

    def Print(self):
        print('Brand: {brand} EngineVolume = {EngineVolume}}'.format(brand = self.Brand, EngineVolume = self.EngineVolume))

# %%
moto = NewMoto('Yamaha',250)

# %%
moto.Print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 moto.Print()
#
# Cell In [15], line 7, in NewMoto.Print(self)
#       6 def Print(self):
# ----> 7     print('Brand: {brand} EngineVolume = {EngineVolume}}'.format(brand = self.Brand, EngineVolume = self.EngineVolume))
#
# ValueError: Single '}' encountered in format string

# %%
class NewMoto:
    def __init__(self, brand, volume):
        self.Brand = brand
        self.EngineVolume = volume

    def Print(self):
        print('Brand: {brand} EngineVolume = {EngineVolume}'.format(brand = self.Brand, EngineVolume = self.EngineVolume))

# %%
moto.Print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 moto.Print()
#
# Cell In [15], line 7, in NewMoto.Print(self)
#       6 def Print(self):
# ----> 7     print('Brand: {brand} EngineVolume = {EngineVolume}}'.format(brand = self.Brand, EngineVolume = self.EngineVolume))
#
# ValueError: Single '}' encountered in format string

# %%
moto = NewMoto('Yamaha', 250)

# %%
moto.Print()
# Out:
# Brand: Yamaha EngineVolume = 250

# %%
# lists

# %%
motos = {'Honda', 'Yamaha', "Kawasaki", 'Suzuki'}

# %%
motos[1:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 motos[1:2]
#
# TypeError: 'set' object is not subscriptable

# %%
motos = list(motos)

# %%
motos[1:2]
# Out:
# ['Honda']

# %%
motos[1]
# Out:
# 'Honda'

# %%
motos[1:]
# Out:
# ['Honda', 'Yamaha', 'Suzuki']

# %%
motos
# Out:
# ['Kawasaki', 'Honda', 'Yamaha', 'Suzuki']

# %%
motos[:1]
# Out:
# ['Kawasaki']

# %%
motos[:2]
# Out:
# ['Kawasaki', 'Honda']

# %%
motos.append('BMW')

# %%
motos
# Out:
# ['Kawasaki', 'Honda', 'Yamaha', 'Suzuki', 'BMW']

# %%
motos[2:4]
# Out:
# ['Yamaha', 'Suzuki']

# %%
motos.sort()

# %%
motos
# Out:
# ['BMW', 'Honda', 'Kawasaki', 'Suzuki', 'Yamaha']

# %%
motosSet = set(motos)

# %%
list(motosSet)
# Out:
# ['Kawasaki', 'Honda', 'Suzuki', 'Yamaha', 'BMW']

# %%
motosS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [39], line 1
# ----> 1 motosS
#
# NameError: name 'motosS' is not defined

# %%
motosSet
# Out:
# {'BMW', 'Honda', 'Kawasaki', 'Suzuki', 'Yamaha'}

# %%
tmp = list(motosSet)

# %%
tmp1 = sorted(tmp)

# %%
tmp
# Out:
# ['Kawasaki', 'Honda', 'Suzuki', 'Yamaha', 'BMW']

# %%
tmp1
# Out:
# ['BMW', 'Honda', 'Kawasaki', 'Suzuki', 'Yamaha']

# %%
motosSet
# Out:
# {'BMW', 'Honda', 'Kawasaki', 'Suzuki', 'Yamaha'}

# %%
motosSet.add('KTM')

# %%
motosSet
# Out:
# {'BMW', 'Honda', 'KTM', 'Kawasaki', 'Suzuki', 'Yamaha'}

# %%
motosSet.add('BMW')

# %%
motosSet
# Out:
# {'BMW', 'Honda', 'KTM', 'Kawasaki', 'Suzuki', 'Yamaha'}

# %%
motosTuple = tuple(motos)

# %%
motosTuple
# Out:
# ('BMW', 'Honda', 'Kawasaki', 'Suzuki', 'Yamaha')

# %%
motosTuple.append('M1NSK')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [52], line 1
# ----> 1 motosTuple.append('M1NSK')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
motos
# Out:
# ['BMW', 'Honda', 'Kawasaki', 'Suzuki', 'Yamaha']

# %%
volumes = [750,1000,450,250,250]

# %%
motosDict = { brand : volume for brand,volume in motos,volumes}
# Out:
#   Cell In [55], line 1
#     motosDict = { brand : volume for brand,volume in motos,volumes}
#                                                           ^
# SyntaxError: invalid syntax

# %%
motosDict = { brand : volume for brand in motos for volume in volumes}

# %%
motosDict
# Out:
# {'BMW': 250, 'Honda': 250, 'Kawasaki': 250, 'Suzuki': 250, 'Yamaha': 250}
